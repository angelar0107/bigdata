# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")
train = pd.read_csv('train_V2.csv')

# %%
matchModes = set(train['matchType'])
print(matchModes)
# Out:
# {'normal-solo-fpp', 'normal-duo', 'normal-squad', 'duo-fpp', 'duo', 'squad', 'normal-squad-fpp', 'flaretpp', 'normal-duo-fpp', 'crashtpp', 'crashfpp', 'flarefpp', 'solo-fpp', 'normal-solo', 'squad-fpp', 'solo'}

# %%
plt.figure(figsize=(20,10))
sns.countplot(train['matchType'],palette="husl")
plt.title('Match Mode Distribution',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(train['matchType'].sort_values(),palette="Paired")
plt.title('Match Mode Distribution',fontsize=15)
plt.show()

# %%
def modifyMatchType(data):
    data['matchType'][data['matchType'] == 'normal-solo'] = 'solo'
    data['matchType'][data['matchType'] == 'solo-fpp'] = 'solo'
    data['matchType'][data['matchType'] == 'normal-solo-fpp'] = 'solo'
    data['matchType'][data['matchType'] == 'normal-duo-fpp'] = 'duo'
    data['matchType'][data['matchType'] == 'normal-duo'] = 'duo'
    data['matchType'][data['matchType'] == 'duo-fpp'] = 'duo'
    data['matchType'][data['matchType'] == 'squad-fpp'] = 'squad'
    data['matchType'][data['matchType'] == 'normal-squad'] = 'squad'
    data['matchType'][data['matchType'] == 'normal-squad-fpp'] = 'squad'
    data['matchType'][data['matchType'] == 'flaretpp'] = 'Other'
    data['matchType'][data['matchType'] == 'flarefpp'] = 'Other'
    data['matchType'][data['matchType'] == 'crashtpp'] = 'Other'
    data['matchType'][data['matchType'] == 'crashfpp'] = 'Other'

    return data


data = train.copy()
data = modifyMatchType(data)
print (set(data['matchType']))
# Out:
# {'duo', 'Other', 'squad', 'solo'}

# %%
data = train.copy()
data = modifyMatchType(data)
plt.figure(figsize=(15,10))
sns.countplot(data['matchType'],palette="cubehelix_r")
plt.title('Modified Match Mode Distribution',fontsize=15)
plt.show()

# %%
data[data['matchType']=='Other']
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 1093     c8ed6a171536e3  84748458aba82a  d4f1811cf6a04b        1       3
# 1207     fb785deb59f2bc  4438f77ac9f2e6  33d976b454b843        0       4
# 1276     d3c4dd2e585d21  6af9bb6b56b722  16e6befa897b44        0       0
# 1524     b0fbbe07014fcd  7ce6194a5dd609  e330f44c528e6f        0       0
# 1790     28390372a2cc4f  c529d05da4597b  be945f2803814a        0       0
# 1905     fd39e397db5de4  67d1056e060313  ab05fc989cba70        0       2
# 2111     1f2775b6f994ae  580347c80ae6a3  098b32c9c9ceb3        0       0
# 2592     5ccc7597791b85  59468d09f86e8a  31e152f644e550        0       0
# 2789     ca51d0bf25412d  b55d170af46a7f  4488d50322ac9b        0       3
# 2887     d1f525f1e237f4  d45f1a797f95d2  784889e9b79717        0       0
# 3831     5ab6f3214e100a  31b5dea4455101  8b84d175271790        0       1
# 4425     52366b9ed49fc0  078bcb11636170  f8dbb6134bf6fc        0       0
# ...

# %%
data = train.copy()
data = modifyMatchType(data)
squad = data[data['matchType']=='squad']
duo = data[data['matchType']=='duo']
solo = data[data['matchType']=='solo']
other_ = data[data['matchType']=='Other']
f,ax1 = plt.subplots(figsize =(20,10))
sns.set_style("darkgrid")
sns.pointplot(x='kills',y='winPlacePerc',data=squad,color='#8B0000',alpha=0.8)
sns.pointplot(x='kills',y='winPlacePerc',data=duo,color='#E9967A',alpha=0.8)
sns.pointplot(x='kills',y='winPlacePerc',data=solo,color='#8FBC8F',alpha=0.8)
sns.pointplot(x='kills',y='winPlacePerc',data=other_,color='#4169E1',alpha=0.8)
plt.text(4,0.6,'Squad',color='#8B0000',fontsize = 30)
plt.text(4,0.5,'Duo',color='#E9967A',fontsize = 30)
plt.text(4,0.4,'Solo',color='#8FBC8F',fontsize = 30)
plt.text(4,0.3,'Others',color='#4169E1',fontsize = 30)
plt.xlabel('Kills',fontsize = 15)
plt.ylabel('Percentage of Win',fontsize = 15)
plt.show()

# %%
data = train.copy()
data = modifyMatchType(data)
squad = data[data['matchType']=='squad']
duo = data[data['matchType']=='duo']
solo = data[data['matchType']=='solo']
other_ = data[data['matchType']=='Other']
f,ax1 = plt.subplots(figsize =(20,10))
sns.set_style("darkgrid")
sns.pointplot(x='damageDealt',y='winPlacePerc',data=squad,color='#8B0000',alpha=0.8)
sns.pointplot(x='damageDealt',y='winPlacePerc',data=duo,color='#E9967A',alpha=0.8)
sns.pointplot(x='damageDealt',y='winPlacePerc',data=solo,color='#8FBC8F',alpha=0.8)
sns.pointplot(x='damageDealt',y='winPlacePerc',data=other_,color='#4169E1',alpha=0.8)
plt.text(4,0.6,'Squad',color='#8B0000',fontsize = 30)
plt.text(4,0.5,'Duo',color='#E9967A',fontsize = 30)
plt.text(4,0.4,'Solo',color='#8FBC8F',fontsize = 30)
plt.text(4,0.3,'Others',color='#4169E1',fontsize = 30)
plt.xlabel('Damage Dealt',fontsize = 15)
plt.ylabel('Percentage of Win',fontsize = 15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e0512a2392f9> in <module>()
#       9 sns.pointplot(x='damageDealt',y='winPlacePerc',data=squad,color='#8B0000',alpha=0.8)
#      10 sns.pointplot(x='damageDealt',y='winPlacePerc',data=duo,color='#E9967A',alpha=0.8)
# ---> 11 sns.pointplot(x='damageDealt',y='winPlacePerc',data=solo,color='#8FBC8F',alpha=0.8)
#      12 sns.pointplot(x='damageDealt',y='winPlacePerc',data=other_,color='#4169E1',alpha=0.8)
#      13 plt.text(4,0.6,'Squad',color='#8B0000',fontsize = 30)
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in pointplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize, ax, **kwargs)
#    3146         ax = plt.gca()
#    3147
# -> 3148     plotter.plot(ax)
#    3149     return ax
#    3150
#
# ...

# %%
# Out:
#                 Id         groupId         matchId  assists  boosts  \
# 0   7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1   eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2   1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3   4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4   315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
# 5   ff79c12f326506  289a6836a88d27  bac52627a12114        0       0
# 6   95959be0e21ca3  2c485a1ad3d0f1  a8274e903927a2        0       0
# 7   311b84c6ff4390  eaba5fcb7fc1ae  292611730ca862        0       0
# 8   1a68204ccf9891  47cfbb04e1b1a2  df014fbee741c6        0       0
# 9   e5bb5a43587253  759bb6f7514fd2  3d3031c795305b        0       0
# 10  2b574d43972813  c549efede67ad3  2dd6ddb8320fc1        0       0
# 11  8de328a74658a9  f643df9df3877c  80170383d90003        0       0
# 12  ce4f6ac165705e  da24cdb91969cc  535b5dbd965a94        0       0
# ...
